# %%
from video_receiver import VideoStreamer
import matplotlib.pyplot as plt

# %%
video_streamer = VideoStreamer("10.177.63.229", 10005)
result = video_streamer.get_image_tensor()
print(result.shape)


plt.imshow(result)
plt.title(f"Robot Camera - Image")
plt.axis('off')  # 不显示坐标轴
plt.show()
# Out:
# (240, 426, 3)
